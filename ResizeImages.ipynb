# %%
#Source: https://stackoverflow.com/questions/21517879/python-pil-resize-all-images-in-a-folder
from PIL import Image
import os, sys

#path = "/Users/Tory/Desktop/CASIASmall/1/"
#dirs = os.listdir( path )

w = 18
h = 16

def resize():
    for item in dirs:
        print(path+item)
        if os.path.isfile(path+item):
            im = Image.open(path+item)
            f, e = os.path.splitext(path+item)
            imResize = im.resize((100,100), Image.ANTIALIAS)
            imResize.save(f, 'JPEG', quality=90)
            
def betterResize():
    for i in range(1,109):
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_1.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_2.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_3.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_1.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_2.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_3.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_4.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((w,h), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        
betterResize()

# %%
#Source: https://stackoverflow.com/questions/21517879/python-pil-resize-all-images-in-a-folder
from PIL import Image
import os, sys

def rescaleUp():
    for i in range(1,109):
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_1.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_2.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_1_3.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_1.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS) 
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_2.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_3.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        path = "/Users/Tory/Desktop/CASIA175/" + str(i) + "/"
        threeDigI = format(i, '03d')
        item = threeDigI + "_2_4.jpg"
        im = Image.open(path+item)
        f, e = os.path.splitext(path+item)
        imResize = im.resize((320,280), Image.ANTIALIAS)
        imResize.save(f + ".jpg", 'JPEG', quality=90)
        
rescaleUp()
